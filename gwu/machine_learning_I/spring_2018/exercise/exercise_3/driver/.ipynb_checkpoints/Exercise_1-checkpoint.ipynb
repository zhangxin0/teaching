# %%
# Exercise_1.ipynb
# This is the Driver file for Exercise 1 of course:
# Machine Learning I (DATS 6202, Spring 2018)
# Data Science @ George Washington University
# Author: Yuxiao Huang

# %%
# Reference:
# The code is from the "Python Machine Learning (2nd edition)" book code repository and info resource
# with some trivial changes by Yuxiao Huang

# Please find the reference to and website of the book below:
# Raschka S. and Mirjalili V. (2017). Python Machine Learning. 2nd Edition.
# https://sebastianraschka.com/books.html

# Please find the website of the book code repository and info resource below:
# https://github.com/rasbt/python-machine-learning-book-2nd-edition

# %%
import pandas as pd

# %%
# Load Bike Sharing data ('hour.csv') and return the first five rows
# Implement me
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# The columns of the explanatory and target variables
cols = ['temp', 'cnt']

# Plot pairwise relationships between 'temp' and 'cnt'
# Implement me

# %%
import numpy as np

# Get Pearson product-moment correlation coefficients
# Implement me

# Get heat map
plt.figure(figsize=(4,4))
hm = sns.heatmap(cm,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.2f',
                 annot_kws={'size': 15},
                 yticklabels=cols,
                 xticklabels=cols)

# Show heat map
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Randomly choose 70% of the data for training
# Implement me

# %%
from sklearn.preprocessing import MinMaxScaler

# min-max normalization
# Implement me

# %%
from sklearn.preprocessing import StandardScaler

# Standardization
# Implement me

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Linear regression
# Draw the residual plot and print the mean squared error
# Here, parameter Sclaer is the scaler used for scaling
def linear_regression(X_train, y_train, X_test, y_test, Scaler):
    # Implement me

# %%
# Linear regression using the three kinds of data (raw, normalized, and standardized)
# Draw the residual plot and print the mean squared error
# Hint: call the function that we defined above
# Implement me
# Out:
# Mean squared error: 27405.954
# Mean squared error: 27405.954
# Mean squared error: 27405.954
